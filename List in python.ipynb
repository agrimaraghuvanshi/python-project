# %%
thislist = ["aarna","mahak","agrima","shivani","saloni","khadija","ira","prisha","vidhi","wilyn","ananya","shreya"]
print(thislist)
# Out:
# ['aarna', 'mahak', 'agrima', 'shivani', 'saloni', 'khadija', 'ira', 'prisha', 'vidhi', 'wilyn', 'ananya', 'shreya']

# %%
thislist = ["aarna","mahak","agrima","shivani","saloni","khadija","ira","prisha","vidhi","wilyn","ananya","shreya"]
print(len(thislist))
# Out:
# 12

# %%
thislist = ["aarna","mahak","agrima","shivani","saloni","khadija","ira","prisha","vidhi","wilyn","ananya","shreya"]
print(thislist[1])
# Out:
# mahak

# %%
thislist = ["aarna","mahak","agrima","shivani","saloni","khadija","ira","prisha","vidhi","wilyn","ananya","shreya"]
print(thislist[-1])
# Out:
# shreya

# %%
thislist = ["aarna","mahak","agrima","shivani","saloni","khadija","ira","prisha","vidhi","wilyn","ananya","shreya"]
print(thislist[2:5])
# Out:
# ['agrima', 'shivani', 'saloni']

# %%
thislist = ["aarna","mahak","agrima","shivani","saloni","khadija","ira","prisha","vidhi","wilyn","ananya","shreya"]
print(thislist[:5])
# Out:
# ['aarna', 'mahak', 'agrima', 'shivani', 'saloni']

# %%
thislist = ["aarna","mahak","agrima","shivani","saloni","khadija","ira","prisha","vidhi","wilyn","ananya","shreya"]
print(thislist[2:])
# Out:
# ['agrima', 'shivani', 'saloni', 'khadija', 'ira', 'prisha', 'vidhi', 'wilyn', 'ananya', 'shreya']

# %%
thislist = ["aarna","mahak","agrima","shivani","saloni","khadija","ira","prisha","vidhi","wilyn","ananya","shreya"]
print(thislist[-5:-1])
# Out:
# ['prisha', 'vidhi', 'wilyn', 'ananya']

# %%
thislist = ["aarna","mahak","agrima","shivani","saloni","khadija","ira","prisha","vidhi","wilyn","ananya","shreya"]
if "mahak" in thislist:
    print("yes,'mahak' is in class list")
# Out:
# yes,'mahak' is in class list

# %%
thislist = ["aarna","mahak","agrima","shivani","saloni","khadija","ira","prisha","vidhi","wilyn","ananya","shreya"]
thislist[1] = "rishika"
print(thislist)
# Out:
# ['aarna', 'rishika', 'agrima', 'shivani', 'saloni', 'khadija', 'ira', 'prisha', 'vidhi', 'wilyn', 'ananya', 'shreya']

# %%
thislist = ["aarna","mahak","agrima","shivani","saloni","khadija","ira","prisha","vidhi","wilyn","ananya","shreya"]
thislist[1:3] =[ "rishika" ,  "ishika"]
print(thislist)
# Out:
# ['aarna', 'rishika', 'ishika', 'shivani', 'saloni', 'khadija', 'ira', 'prisha', 'vidhi', 'wilyn', 'ananya', 'shreya']

# %%
thislist = ["aarna","mahak","agrima","shivani","saloni","khadija","ira","prisha","vidhi","wilyn","ananya","shreya"]
thislist.insert(2,"rishika")
print(thislist)
# Out:
# ['aarna', 'mahak', 'rishika', 'agrima', 'shivani', 'saloni', 'khadija', 'ira', 'prisha', 'vidhi', 'wilyn', 'ananya', 'shreya']

# %%
thislist = ["aarna","mahak","agrima","shivani","saloni","khadija","ira","prisha","vidhi","wilyn","ananya","shreya"]
thislist.append("aayushi")
print(thislist)
# Out:
# ['aarna', 'mahak', 'agrima', 'shivani', 'saloni', 'khadija', 'ira', 'prisha', 'vidhi', 'wilyn', 'ananya', 'shreya', 'aayushi']

# %%
thislist = ["aarna","mahak","agrima","shivani","saloni","khadija","ira","prisha","vidhi","wilyn","ananya","shreya"]
thislist.insert(1,"simran")
print(thislist)
# Out:
# ['aarna', 'simran', 'mahak', 'agrima', 'shivani', 'saloni', 'khadija', 'ira', 'prisha', 'vidhi', 'wilyn', 'ananya', 'shreya']

# %%
thislist = ["aarna","mahak","agrima","shivani","saloni","khadija","ira","prisha","vidhi","wilyn","ananya","shreya"]
thislist.remove("aarna")
print(thislist)
# Out:
# ['mahak', 'agrima', 'shivani', 'saloni', 'khadija', 'ira', 'prisha', 'vidhi', 'wilyn', 'ananya', 'shreya']

# %%
thislist = ["aarna","mahak","agrima","shivani","saloni","khadija","ira","prisha","vidhi","wilyn","ananya","shreya"]
thislist.pop(1)
print(thislist)
# Out:
# ['aarna', 'agrima', 'shivani', 'saloni', 'khadija', 'ira', 'prisha', 'vidhi', 'wilyn', 'ananya', 'shreya']

# %%
thislist = ["aarna","mahak","agrima","shivani","saloni","khadija","ira","prisha","vidhi","wilyn","ananya","shreya"]
del thislist[0]
print(thislist)
# Out:
# ['mahak', 'agrima', 'shivani', 'saloni', 'khadija', 'ira', 'prisha', 'vidhi', 'wilyn', 'ananya', 'shreya']
