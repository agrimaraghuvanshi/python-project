# %%
players = ["Rohit", "Virat", "Rahul", "Hardik", "Bumrah"]
players.append("Surya")
print(players)
# Out:
# ['Rohit', 'Virat', 'Rahul', 'Hardik', 'Bumrah', 'Surya']

# %%
players = ["Rohit", "Virat", "Rahul", "Hardik", "Bumrah"]
players.insert(0, "Dhoni")
print(players)
# Out:
# ['Dhoni', 'Rohit', 'Virat', 'Rahul', 'Hardik', 'Bumrah']

# %%
players = ["Rohit", "Virat", "Rahul", "Hardik", "Bumrah"]
players[2] = "Pant"
print(players)
# Out:
# ['Rohit', 'Virat', 'Pant', 'Hardik', 'Bumrah']

# %%
players = ["Rohit", "Virat", "Rahul", "Hardik", "Bumrah"]
players.remove("Hardik")
print(players)
# Out:
# ['Rohit', 'Virat', 'Rahul', 'Bumrah']

# %%
players = ["Rohit", "Virat", "Rahul", "Hardik", "Bumrah"]
print("First 3 players:", players[:3])
# Out:
# First 3 players: ['Rohit', 'Virat', 'Rahul']

# %%
players = ["Rohit", "Virat", "Rahul", "Hardik", "Bumrah"]
players.sort()

print("Alphabetically sorted team:", players)
# Out:
# Alphabetically sorted team: ['Bumrah', 'Hardik', 'Rahul', 'Rohit', 'Virat']
