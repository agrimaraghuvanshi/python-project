# %%
items = ["Milk", "Bread", "Eggs", "Butter"]
items.append("Cheese")
print(items)
# Out:
# ['Milk', 'Bread', 'Eggs', 'Butter', 'Cheese']

# %%
items = ["Milk", "Bread", "Eggs", "Butter"]
items.insert(2, "Juice")
print(items)
# Out:
# ['Milk', 'Bread', 'Juice', 'Eggs', 'Butter']

# %%
items = ["Milk", "Bread", "Eggs", "Butter"]
items[2] = "Chocolate"
print(items)
# Out:
# ['Milk', 'Bread', 'Chocolate', 'Butter']

# %%
items = ["Milk", "Bread", "Eggs", "Butter"]
items.remove("Bread")
print(items)
# Out:
# ['Milk', 'Eggs', 'Butter']

# %%
items = ["Milk", "Bread", "Eggs", "Butter"]
print("First 3 items:", items[:3])
# Out:
# First 3 items: ['Milk', 'Bread', 'Eggs']

# %%
items = ["Milk", "Bread", "Eggs", "Butter"]
print("Complete list:", items)
# Out:
# Complete list: ['Milk', 'Bread', 'Eggs', 'Butter']
